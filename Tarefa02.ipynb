# %% [markdown]
# <a href="https://colab.research.google.com/github/marescost4/Mariane-David-Fillipy/blob/main/Tarefa02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bioestatística tarefa 2
#
# - David Souza 16965966
# - Mariane Santana 16890981
# - Fillipy Leal 17097358

# %%
import pandas as pd
df= pd.read_excel("Tarefa02.xlsx")
df.head(21)
# Out:
#        FRUTAS  PESO_g  PRECO_R$
# 0      banana     682        40
# 1         uva     968        39
# 2       cacau     774        38
# 3    graviola     630        37
# 4     cupuaçu     777        36
# 5       limão     734        35
# 6    laranja      781        34
# 7   tangerina     409        33
# 8       mamão     571        32
# 9       caqui     825        31
# 10     sapoti     765        30
# 11       jaca     407        29
# 12      melão     245        28
# 13   melancia     423        27
# 14   maracujá     434        26
# 15     goiaba     413        25
# 16  carambola     413        24
# 17      pinha     399        23
# 18    abacate     979        22
# 19    abacaxi     920        21

# %%
print("Quantidade de linhas:", len(df))
print("Quantidade de colunas:", len(df.columns))

df.info()
# Out:
# Quantidade de linhas: 20
# Quantidade de colunas: 4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FRUTAS       20 non-null     object
#  1   PESO_g       20 non-null     int64
#  2   PRECO_R$     20 non-null     int64
#  3   FAIXA_PRECO  20 non-null     category
# dtypes: category(1), int64(2), object(1)
# memory usage: 764.0+ bytes

# %%
df["FAIXA_PRECO"] = pd.cut(df["PRECO_R$"],bins=[20, 27, 34, 40],labels=["Baixo", "Médio", "Alto"], include_lowest=True)

# %%
contagem = df["FAIXA_PRECO"].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(contagem, labels=contagem.index, autopct="%1.1f%%",startangle=90)
plt.title("Distribuição das Frutas por Faixa de Preço")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df["FRUTAS"], df["PRECO_R$"], color="green")
plt.title("Preço das Frutas")
plt.xlabel("Frutas")
plt.ylabel("Preço (R$)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df["PESO_g"])
plt.title("Distribuição do Peso das Frutas")
plt.ylabel("Peso (g)")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df["PESO_g"],bins=6)
plt.title("Distribuição do Peso das Frutas")
plt.xlabel("Peso (g)")
plt.ylabel("Quantidade de Frutas")
plt.show()
