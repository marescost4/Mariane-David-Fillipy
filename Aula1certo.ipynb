# %% [markdown]
# <a href="https://colab.research.google.com/github/marescost4/a/blob/main/Aula1certo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bioestatística
#
# - David Souza 16965966
# - Mariane Santana 16890981
# - Fillipy Leal 17097358
#
# # Tipos de variáveis
#
# ## Discreta
#
# Número de bacterias numa suspensão (50.000 bactérias em 1 ml de água destilada)
#
# ## Continua
#
# Comprimento da parte aérea de sementes germinadas em cm (0.1, 0.5, ..., 1)
#
# ## Ordinal
#
# Grau de escolaridade (básico, médio, superior)
#
# ## Nominal
#
# Disciplinas da área de biológicas (Bioquímica, Zoologia, Histologia, Anatomia, Ecologia)

# %%
import pandas as pd

df = pd.read_excel('dados.xlsx')

# %%
df
# Out:
#     Quantos dias por semana você estuda Biologia?  \
# 0                                               5
# 1                                               6
# 2                                               5
# 3                                               5
# 4                                               5
# 5                                               3
# 6                                               5
# 7                                               5
# 8                                               7
# 9                                               5
# 10                                              6
# 11                                              6
# 12                                              5
# 13                                              5
# 14                                              6
# 15                                              6
# 16                                              6
# 17                                              2
# ...

# %%
df.head(7)
# Out:
#    Quantos dias por semana você estuda Biologia?  \
# 0                                              5
# 1                                              6
# 2                                              5
# 3                                              5
# 4                                              5
# 5                                              3
# 6                                              5
#
#    Quantas horas você dedica aos estudos de Biologia em uma semana?  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 30
# 4                                                 20
# 5                                                  8
# 6                                                 10
#
#    Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  \
# ...

# %%
df.tail(7)
# Out:
#     Quantos dias por semana você estuda Biologia?  \
# 16                                              6
# 17                                              2
# 18                                              2
# 19                                              6
# 20                                              5
# 21                                              6
# 22                                              5
#
#     Quantas horas você dedica aos estudos de Biologia em uma semana?  \
# 16                                                 24
# 17                                                 10
# 18                                                  8
# 19                                                 30
# 20                                                 10
# 21                                                 15
# 22                                                 12
#
#     Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Quantos dias por semana você estuda Biologia?                                                 23 non-null     int64
#  1   Quantas horas você dedica aos estudos de Biologia em uma semana?                              23 non-null     int64
#  2   Quantas espécies de plantas você consegue identificar corretamente em uma atividade prática?  23 non-null     int64
#  3   Qual o tamanho da folha analisada, em milímetros?                                             23 non-null     object
#  4   Qual o nível de dificuldade da atividade prática?                                             23 non-null     object
# ...
